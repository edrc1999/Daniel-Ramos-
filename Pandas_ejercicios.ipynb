# %% [markdown]
# <a href="https://colab.research.google.com/github/edrc1999/Daniel-Ramos-/blob/main/Pandas_ejercicios.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Taller básico pandas - numpy

# %%
import pandas as pd

# %%
# Crear un dataframe que tenga 3 registros(filas) cada una debe contener el nombre de una cancion, el artista que la canta, y la duracion en segundos
canciones = [
    {'Nombre': 'Vape', 'Artista': 'Juancho', 'Duracion (segundos)': 260},
    {'Nombre': 'Twoo sweet', 'Artista': 'Hozier', 'Duracion (segundos)': 179},
    {'Nombre': 'Brillarosa', 'Artista': 'Fuerza Regida', 'Duracion (segundos)': 280}
]

canciones

can = pd.DataFrame(canciones)

# %%
# Imprimir la cola del dataframe
can
# Out:
#        Nombre        Artista  Duracion (segundos)
# 0        Vape        Juancho                  260
# 1  Twoo sweet         Hozier                  179
# 2  Brillarosa  Fuerza Regida                  280

# %%
# Acceder a la columna duracion
can["Duracion (segundos)"]
# Out:
# 0    260
# 1    179
# 2    280
# Name: Duracion (segundos), dtype: int64

# %%
# Calcular el promedio de las duraciones
prom = can["Duracion (segundos)"].mean()
prom
# Out:
# 239.66666666666666

# %%
# Obtener los nombres de las canciones que tengan duracion mayor que el promedio
CancionesMayor = can["Duracion (segundos)"]>prom
CancionesMayor
# Out:
# 0     True
# 1    False
# 2     True
# Name: Duracion (segundos), dtype: bool

# %%
# Agregar una columna al dataframe que contenga True si la duracion es mayor que 3 minutos
# y false si es menor
can["Duracion mas de 3 min"]=can["Duracion (segundos)"]>180
can
# Out:
#        Nombre        Artista  Duracion (segundos)  Duracion mas de 3 min
# 0        Vape        Juancho                  260                   True
# 1  Twoo sweet         Hozier                  179                  False
# 2  Brillarosa  Fuerza Regida                  280                   True

# %%
# Convertir el dataframe a numpy array
array_npy = can.to_numpy()
array_npy
# Out:
# array([['Vape', 'Juancho', 260, True],
#        ['Twoo sweet', 'Hozier', 179, False],
#        ['Brillarosa', 'Fuerza Regida', 280, True]], dtype=object)

# %%
# Imprimir el shape del array
array_npy.shape
# Out:
# (3, 4)

# %%
# Hacer un reshape para convertir el arreglo de 3x3 a un arreglo de 12 elementos
array_npy.reshape(2,6)
# Out:
# array([['Vape', 'Juancho', 260, True, 'Twoo sweet', 'Hozier'],
#        [179, False, 'Brillarosa', 'Fuerza Regida', 280, True]],
#       dtype=object)

# %%
array_npy.reshape(6,2)
# Out:
# array([['Vape', 'Juancho'],
#        [260, True],
#        ['Twoo sweet', 'Hozier'],
#        [179, False],
#        ['Brillarosa', 'Fuerza Regida'],
#        [280, True]], dtype=object)
